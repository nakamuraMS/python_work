# %%
# https://signate.jp/competitions/24/tutorials/3
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(font="IPAexGothic",style="white")

# %%
train = pd.read_csv("./original/train.csv")
test = pd.read_csv("./original/test.csv")
sample = pd.read_csv("./original/sample.csv",header=None)
print("Data Shapes")
print("Train:",train.shape, "Test:",test.shape, "Sample:",sample.shape) # それぞれ行数と列数を表示
# Out:
# Data Shapes
# Train: (207, 12) Test: (40, 11) Sample: (40, 2)

# %%
train.index = pd.to_datetime(train["datetime"])
train.head()
# Out:
#               datetime    y week  soldout        name  kcal remarks event  \
# datetime
# 2013-11-18  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN
# 2013-11-19  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN
# 2013-11-20  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN
# 2013-11-21  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN
# 2013-11-22  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN
#
#             payday weather precipitation  temperature
# datetime
# 2013-11-18     NaN      快晴            --         19.8
# 2013-11-19     NaN      快晴            --         17.0
# 2013-11-20     NaN      快晴            --         15.5
# 2013-11-21     NaN      快晴            --         15.2
# 2013-11-22     NaN      快晴            --         16.1

# %%
train.describe()
# Out:
#                 y     soldout        kcal  payday  temperature
# count  207.000000  207.000000  166.000000    10.0   207.000000
# mean    86.623188    0.449275  404.409639     1.0    19.252174
# std     32.882448    0.498626   29.884641     0.0     8.611365
# min     29.000000    0.000000  315.000000     1.0     1.200000
# 25%     57.000000    0.000000  386.000000     1.0    11.550000
# 50%     78.000000    0.000000  408.500000     1.0    19.800000
# 75%    113.000000    1.000000  426.000000     1.0    26.100000
# max    171.000000    1.000000  462.000000     1.0    34.600000

# %%
train.describe(include="O")
# Out:
#           datetime week   name   remarks event weather precipitation
# count          207  207    207        21    14     207           207
# unique         207    5    156         6     2       7             8
# top     2013-11-18    水  メンチカツ  お楽しみメニュー  ママの会      快晴            --
# freq             1   43      6        12     9      53           169

# %%
train["payday"] = train["payday"].fillna(0)
train["precipitation"] = train["precipitation"].apply(lambda x: -1 if x=="--" else float(x))
train["event"] = train["event"].fillna("なし")
train["remarks"] = train["remarks"].fillna("なし")
train["month"] = train["datetime"].apply(lambda x : int(x.split("-")[1]))

# %%
train['y'].plot(figsize=(15, 4))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
fig, ax = plt.subplots(2, 3, figsize=(9, 6))
train.plot.scatter(x="soldout", y="y", ax=ax[0][0])
train.plot.scatter(x="kcal", y="y", ax=ax[0][1])
train.plot.scatter(x="precipitation", y="y", ax=ax[0][2])
train.plot.scatter(x="payday", y="y", ax=ax[1][0])
train.plot.scatter(x="temperature", y="y", ax=ax[1][1])
train.plot.scatter(x="month", y="y", ax=ax[1][2])
plt.tight_layout()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
fig, ax = plt.subplots(2,2,figsize=(12,7))
sns.boxplot(x="week", y="y", data=train, ax=ax[0][0])
sns.boxplot(x="weather", y="y", data=train, ax=ax[0][1])
sns.boxplot(x="remarks", y="y", data=train, ax=ax[1][0])
ax[1][0].set_xticklabels(ax[1][0].get_xticklabels(), rotation=30)
sns.boxplot(x="event", y="y", data=train, ax=ax[1][1])
plt.tight_layout()
# Out:
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 28779 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 27700 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 38632 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 38634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 38647 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 38651 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12394 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12375 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 40335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12524 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12514 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12531 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12506 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12483 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12497 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 28988 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 39135 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12459 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 37218 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 35930 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12362 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 27005 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12415 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12513 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12491 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26009 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 29702 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 38263 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12371 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12384 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12431 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12426 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25163 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20316 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12471 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12515 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12523 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20870 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12510 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20250 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12461 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12522 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12503 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25903 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12511 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12490 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26376 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 28779 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 27700 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26311 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 38632 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 38634 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 38647 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 38651 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12394 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12375 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 40335 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12524 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12514 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12531 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12506 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12483 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12497 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 28988 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 39135 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12459 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 37218 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 35930 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12362 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 27005 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12415 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12513 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12491 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12517 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26009 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 29702 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 38263 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12371 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12384 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12431 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12426 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25163 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20316 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21619 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12471 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12515 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12523 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20870 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12510 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20250 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12461 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12522 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12450 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12503 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25903 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25588 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12475 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12511 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\nakamura\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12490 missing from current font.
#   font.set_text(s, 0, flags=flags)
