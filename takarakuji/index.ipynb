# %%
import numpy as np
from sklearn.metrics import r2_score
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
# %matplotlib inline

import seaborn as sns
import pandas as pd

# import utils as Util
# Out:
# c:\Users\nakamura\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
train = pd.read_csv("./data/NUMBERS4_ALL.csv")
train
# Out:
#         No         抽選日  当選数字  口数[ストレート]  口数[ボックス]  口数[セット・ストレート]  \
# 0        1  1994/10/07  1149          0         0              0
# 1        2  1994/10/14  7921          0         0              0
# 2        3  1994/10/21    97          0         0              0
# 3        4  1994/10/28   171          0         0              0
# 4        5  1994/11/04   265          0         0              0
# ...    ...         ...   ...        ...       ...            ...
# 6290  6291  2023/09/05  1115         67        80            184
# 6291  6292  2023/09/06  2988         34       111             73
# 6292  6293  2023/09/07  9398         21       214             57
# 6293  6294  2023/09/08  6470         20       402             53
# 6294  6295  2023/09/11  1134         47       249            101
#
#       口数[セット・ボックス]  金額[ストレート]  金額[ボックス]  金額[セット・ストレート]  金額[セット・ボックス]  \
# 0                0     942600     78500         510500         39200
# 1                0     923700     38400         481000         19200
# 2                0    1516600    126300         821400         63100
# 3                0     579400     48200         313800         24100
# 4                0    1222900     50900         636900         25400
# ...            ...        ...       ...            ...           ...
# 6290           141     415800    103900         259800         51900
# 6291           519     881500     73400         477400         36700
# 6292           727     933800     77800         505800         38900
# 6293          1564     995700     41400         518500         20700
# 6294           860     669600     55800         362700         27900
#
#            販売実績
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 6290  202973600
# 6291  204553800
# 6292  207517800
# 6293  214499600
# 6294  235561600
#
# [6295 rows x 12 columns]

# %%
plt.figure(figsize=(16,6))
plt.title('当選数字')
plt.plot(train['当選数字'])
plt.xlabel('No', fontsize=14)
plt.ylabel('当選数字', fontsize=14)
plt.show()
